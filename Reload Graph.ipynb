# %%
import networkx as nx

# %%
G=nx.read_gpickle("full_graph.gpickle")

# %%
list(G.nodes(data=True))
# Out:
# [((-73.74081689158372, 45.51897292308536),
#   {'ID_TRC': 1010001,
#    'DEB_GCH': 12320,
#    'FIN_GCH': 12340,
#    'ARR_GCH': 'Ahuntsic-Cartierville',
#    'SENS_CIR': 0,
#    'CLASSE': 0,
#    'LIE_VOIE': None,
#    'TYP_VOIE': 'avenue',
#    'DIR_VOIE': None,
#    'NOM_VOIE': 'Adhémar-Mailhiot',
#    'DEB_DRT': 12323,
#    'FIN_DRT': 12335,
#    'ARR_DRT': 'Ahuntsic-Cartierville',
#    'LIM_GCH': 'Montréal',
#    'LIM_DRT': 'Montréal'}),
#  ((-73.7419541040326, 45.519703332189074),
#   {'ID_TRC': 1010001,
#    'DEB_GCH': 12320,
#    'FIN_GCH': 12340,
#    'ARR_GCH': 'Ahuntsic-Cartierville',
#    'SENS_CIR': 0,
#    'CLASSE': 0,
#    'LIE_VOIE': None,
#    'TYP_VOIE': 'avenue',
#    'DIR_VOIE': None,
#    'NOM_VOIE': 'Adhémar-Mailhiot',
#    'DEB_DRT': 12323,
#    'FIN_DRT': 12335,
#    'ARR_DRT': 'Ahuntsic-Cartierville',
#    'LIM_GCH': 'Montréal',
#    'LIM_DRT': 'Montréal'}),
#  ((-73.70623530423325, 45.527646493721306),
#   {'ID_TRC': 1010004,
#    'DEB_GCH': 5530,
# ...
